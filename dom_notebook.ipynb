# %%
import pandas as pd

# %%
disease_signatures = pd.read_table("data/Disease_Signatures_MECFS.tsv", sep="\t")
heads = disease_signatures.columns
disease_signatures[heads[1]] = disease_signatures[heads[1]].str.split(", ")
disease_signatures[heads[2]] = disease_signatures[heads[2]].str.split(", ")

# %%
snp_table = pd.read_table("data/SNP_Table_MECFS.tsv", sep="\t")
snp_table
# Out:
#          SNP ID  Chromosome  Position in Build GRCh37 Variants (Ref/Alt)  \
# 0    rs41306603           1                  33321877                A/C
# 1     rs2985754           1                  39053684                T/C
# 2      rs946448           1                  54661150                C/T
# 3    rs12562306           1                  54662686                G/A
# 4    rs17571877           1                  73987668                G/A
# ..          ...         ...                       ...                ...
# 194  rs10470164          21                  33384319                T/C
# 195  rs13047599          21                  34926260                T/C
# 196   rs2309099          21                  43074513                T/G
# 197  rs11910362          21                  44042101                T/C
# 198   rs5747306          22                  18128960                A/G
#
#      Critical SNP  GWAS p-value (PLINK)  \
# 0               1              0.542700
# ...

# %%
metabolites = pd.read_excel("data/Hoel_et_al_metabolites.xlsx")
metabolites
# Out:
#    SUPPLEMENTARY FILE 2 - METABOLON CLP DATA  \
# 0                                        NaN
# 1                                      SHEET
# 2                         1.Suppl 2 content
# 3                               2.FC & Stats
# 4                           3.FC CLP classes
# 5                              4.psign MEall
# 6                            5.psign Uniform
# 7                              6.psign ME-M1
# 8                              7.psign ME-M2
# 9                              8.psign ME-M3
# 10                                 9.FA Conc
# 11                                10.FA Mol%
#
#                                            Unnamed: 1
# 0                                                 NaN
# 1                                             CONTENT
# 2   Overview of the content in Supplermentary file 2
# 3   Curated CLP metabolite data ME-ALL-M1-M2-M3 vs HC
# 4   Total lipid class concentrations (calculated/e...
# ...

# %%
metabolites.head()
# Out:
#   SUPPLEMENTARY FILE 2 - METABOLON CLP DATA  \
# 0                                       NaN
# 1                                     SHEET
# 2                        1.Suppl 2 content
# 3                              2.FC & Stats
# 4                          3.FC CLP classes
#
#                                           Unnamed: 1
# 0                                                NaN
# 1                                            CONTENT
# 2  Overview of the content in Supplermentary file 2
# 3  Curated CLP metabolite data ME-ALL-M1-M2-M3 vs HC
# 4  Total lipid class concentrations (calculated/e...
